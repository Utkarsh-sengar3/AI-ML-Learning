# %% [markdown]
# <a href="https://colab.research.google.com/github/Utkarsh-sengar3/AI-ML-Learning/blob/main/Unsupervised-Learning/Unsupervised_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# from sklearn.cluster import MiniBatchKMeans
# from sklearn.datasets import make_blobs
# import matplotlib.pyplot as plt

# #Generate synthetic data
# X, y = make_blobs(n_samples = 1000, centers = 3, n_ffeatures = 2, random_state = 42)

# #configure and fir

# %%
import pandas as pd
data = pd.read_csv('iris.data.csv')
print("top 5 rows")
print(data.head())
print("\n bottom 5 rows")
print(data.tail())
# Out:
# top 5 rows
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
#
#  bottom 5 rows
#      5.1  3.5  1.4  0.2     Iris-setosa
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica

# %%
print(data.describe())
print(data.info())
print(data.isnull().sum())
# Out:
#               5.1         3.5         1.4         0.2
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   5.1          149 non-null    float64
#  1   3.5          149 non-null    float64
#  2   1.4          149 non-null    float64
#  3   0.2          149 non-null    float64
#  4   Iris-setosa  149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB
# None
# 5.1            0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_csv(
    "iris.data.csv",
    header=None,
    names=["SepalLength", "SepalWidth",
           "PetalLength", "PetalWidth", "Species"]
)

# %%
#Bar Chart
data.groupby("Species")["PetalLength"].mean().plot(kind="bar")

plt.title("Average Petal Length by Species")
plt.xlabel("Species")
plt.ylabel("Average Petal Length")
plt.xticks(rotation=0)
plt.show()

# %%
# scatter plot
for species in data["Species"].unique():
    subset = data[data["Species"] == species]
    plt.scatter(
        subset["SepalLength"],
        subset["PetalLength"],
        label=species
    )

plt.title("Sepal Length vs Petal Length")
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.legend()
plt.show()

# %%
data = data.dropna()

# %%
X = data[
    ["SepalLength", "SepalWidth",
     "PetalLength", "PetalWidth"]
]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(
    n_clusters=3,
    random_state=42,
    n_init=10
)

# %%
kmeans.fit(X_scaled)
# Out:
# KMeans(n_clusters=3, n_init=10, random_state=42)

# %%
data["cluster"] = kmeans.labels_

# %%
print("cluster centers")
print(kmeans.cluster_centers_)
# Out:
# cluster centers
# [[-0.05021989 -0.88029181  0.34753171  0.28206327]
#  [-1.01457897  0.84230679 -1.30487835 -1.25512862]
#  [ 1.13597027  0.09659843  0.996271    1.01717187]]

# %%
plt.figure(figsize = (8,6))

plt.scatter(
    X_scaled[:,0],
    X_scaled[:,1],
    c=kmeans.labels_,
    s=50
)



plt.scatter(
    kmeans.cluster_centers_[:,0],
    kmeans.cluster_centers_[:,1],
    marker = "X",
    s = 200,
    label = "Centroids"
)

plt.xlabel("Annual Income (k$)")
plt.ylabel("Spending Score (1-100)")
plt.title("Clusters of Customers")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster impoort AgglomerativeClustring
from sklearn.metrics import daviers_bouldin_Score
from scipy.cluster.hierchy import linkage, dendrogram

X, _ = make_blobs(n_samples = 30, centers = 3, random_state = 42)
labels = AgglometricClustering(n_cluster=3, linkage='single').fir_predict(X)
score = davies_bouldin_score(X,labels)

plt.plot()
dendogr
# Out:
#   File "/tmp/ipykernel_3170/579843260.py", line 3
#     from sklearn.cluster impoort AgglomerativeClustring
#                          ^
# SyntaxError: invalid syntax

# %%
#silotte coff is evaluating matrix we evaluate weather we have good clusster or not
# to cheack quality of cluster .

#cohision and sepration
#compare two cluster


from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
scores = []

for k in range (2,7):
  model = KMeans(n_clusters = k, random_state = 42, n_init = 10)
  model.fit(X_scaled)
  labels = model.labels_
  score = silhouette_score(X_scaled, labels)
  scores.append(score)

plt.plot(range(2,7), scores, marker='o')
plt.xlabel("Number of Clusters(K)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score for Different K")
plt.show()
